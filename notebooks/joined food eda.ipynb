# %%
import pandas as pd
from sqlalchemy import create_engine,text

# %%
database_name = 'capstone'
connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"
engine = create_engine(connection_string)

# %%
query = '''
SELECT recipes.recipe_id, 
		title,  
		url, 
		rating, 
		reviews, 
		source, 
		recipes.ingredients AS recipe_ingredients, 
		ingredients.ingredient_id, 
		ingredients.ingredients AS ingredient_name
FROM recipes
	INNER JOIN recipe_ingredients ON recipes.index = recipe_ingredients.recipe_id
	INNER JOIN ingredients USING(ingredient_id)
'''

with engine.connect() as connection:    
    joined_recipes = pd.read_sql(text(query), con = connection)

# %%
joined_recipes
# Out:
#      recipe_id                                              title  \
# 0            0                  Easy Chicken and Broccoli Alfredo
# 1            1                Tex-Mex Pork Chops and Rice Skillet
# 2            4                                      Chicken Bhuna
# 3            8                                  Chicken Al Pastor
# 4            9                                Mississippi Chicken
# ..         ...                                                ...
# 759        111                           Donut Pan Egg Sandwiches
# 760        116                       Mini Sausage Pancake Muffins
# 761        120                        Sweet Potato Breakfast Hash
# 762        189  "A Bologna" - Calamari, Scallops and Clams wit...
# 763        194                          "All Crabmeat" Crab Cakes
#
#                                                    url  rating  reviews  \
# 0    https://www.allrecipes.com/recipe/212498/easy-...     4.4    145.0
# 1    https://www.allrecipes.com/tex-mex-pork-chops-...     4.9      8.0
# 2    https://www.allrecipes.com/chicken-bhuna-recip...     4.0      4.0
# 3    https://www.allrecipes.com/recipe/8509102/chic...     4.4      7.0
# 4    https://www.allrecipes.com/recipe/8508920/miss...     4.5     37.0
# ..                                                 ...     ...      ...
# 759  https://www.allrecipes.com/recipe/8497079/donu...     NaN      NaN
# 760  https://www.allrecipes.com/mini-sausage-pancak...     NaN      NaN
# 761  https://www.allrecipes.com/sweet-potato-breakf...     5.0      2.0
# 762  https://www.foodnetwork.com/recipes/a-bologna-...     5.0      1.0
# 763  https://www.foodnetwork.com/recipes/all-crabme...     0.0      0.0
#
#            source                                 recipe_ingredients  \
# 0      allrecipes   fettuccine      fresh broccoli florets   Zest...
# 1      allrecipes    olive oil   boneless pork chops            t...
# 2      allrecipes    vegetable oil    onions        salt   cloves...
# 3      allrecipes    dried guajillo chiles  stemmed seeded    ach...
# 4      allrecipes    skinless  boneless chicken breasts        dr...
# ..            ...                                                ...
# 759    allrecipes    eggs    salt freshly ground black pepper   c...
# 760    allrecipes    pork sausage    pancake mix      water    sh...
# 761    allrecipes      sweet potatoes       olive oil     salt   ...
# 762  food network      fingerling potatoes  halved lengthwise   o...
# 763  food network        cornflake crumbs   jumbo lump crabmeat  ...
#
#      ingredient_id ingredient_name
# 0                0         chicken
# 1                0         chicken
# 2                0         chicken
# 3                0         chicken
# 4                0         chicken
# ..             ...             ...
# 759             17          chives
# 760             17          chives
# 761             17          chives
# 762             17          chives
# 763             17          chives
#
# [764 rows x 9 columns]

# %%
top_ingredients = joined_recipes.ingredient_name.value_counts().reset_index()
top_ingredients
# Out:
#    ingredient_name  count
# 0            onion     98
# 1              oil     91
# 2           butter     89
# 3           garlic     75
# 4             eggs     63
# 5            sugar     62
# 6            flour     56
# 7             milk     54
# 8          chicken     38
# 9             beef     34
# 10         parsley     33
# 11           lemon     22
# 12            rice     18
# 13         lettuce      9
# 14         peppers      7
# 15          chives      7
# 16            dill      5
# 17            lamb      3
