# %%
import pandas as pd
from sqlalchemy import create_engine,text

# %%
database_name = 'capstone'
connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"
engine = create_engine(connection_string)

# %%
query = '''
SELECT recipes.recipe_id, 
		title,  
		url, 
		rating, 
		reviews, 
		source, 
		recipes.ingredients AS recipe_ingredients, 
		gen_ing.food_id, 
		gen_ing.food_name AS ingredient_name,
        gen_ing.group,
        gen_ing.sub_group
FROM recipes
	INNER JOIN recipe_g_ingredients ON recipes.index = recipe_g_ingredients.recipe_id
	INNER JOIN gen_ing ON ingredient_id = food_id
'''

with engine.connect() as connection:    
    joined_recipes = pd.read_sql(text(query), con = connection)

# %%
joined_recipes
# Out:
#       recipe_id                                              title  \
# 0           220              A Potato Soup with Flaky Potato Knish
# 1             1                Tex-Mex Pork Chops and Rice Skillet
# 2             2                Spicy Canned Salmon Salad Rice Bowl
# 3             3                             Grilled Tomahawk Steak
# 4             4                                      Chicken Bhuna
# ...         ...                                                ...
# 2779        376        5-Spice Pork Stir Fry with Mandarin Oranges
# 2780        382  50/50 Olive Oil/Coconut Oil Blend Healthy Chic...
# 2781        385  6-Minute Egg on Creamy Polenta with Crispy Ser...
# 2782        406    8 Treasure Stuffed Turkey with Shiraz-Honey Jus
# 2783        407           9 Time Pro-Roller - Chicken Spring Rolls
#
#                                                     url  rating  reviews  \
# 0     https://www.foodnetwork.com/recipes/a-potato-s...     3.8      5.0
# 1     https://www.allrecipes.com/tex-mex-pork-chops-...     4.9      8.0
# 2     https://www.allrecipes.com/spicy-canned-salmon...     5.0      1.0
# 3     https://www.allrecipes.com/grilled-tomahawk-st...     4.5      4.0
# 4     https://www.allrecipes.com/chicken-bhuna-recip...     4.0      4.0
# ...                                                 ...     ...      ...
# 2779  https://www.foodnetwork.com/recipes/5-spice-po...     5.0      1.0
# 2780  https://www.foodnetwork.com/recipes/herb-mesa/...     4.3      4.0
# 2781  https://www.foodnetwork.com/recipes/6-minute-e...     0.0      0.0
# 2782  https://www.foodnetwork.com/recipes/8-treasure...     0.0      0.0
# 2783  https://www.foodnetwork.com/recipes/9-time-pro...     3.0      2.0
#
#             source                                 recipe_ingredients  \
# 0     food network       unsalted butter   onion  coarsely    leek...
# 1       allrecipes    olive oil   boneless pork chops            t...
# 2       allrecipes     English cucumber    low sodium soy sauce   ...
# 3       allrecipes  Steak Rub Steak     brown sugar    Montreal st...
# 4       allrecipes    vegetable oil    onions        salt   cloves...
# ...            ...                                                ...
# 2779  food network      peaches      brown sugar    ketchup    app...
# 2780  food network      oil blend     carrots   minced fresh garli...
# 2781  food network     slices Serrano ham  eggs  bunches kale   bu...
# 2782  food network    Canola oil    free range  andorganic turkey ...
# 2783  food network     stalks lemon grass     fish sauce   sugar  ...
#
#       food_id ingredient_name             group                sub_group
# 0           6            Leek        Vegetables  Onion-family vegetables
# 1           7          Garlic  Herbs and Spices                    Herbs
# 2           7          Garlic  Herbs and Spices                    Herbs
# 3           7          Garlic  Herbs and Spices                    Herbs
# 4           7          Garlic  Herbs and Spices                    Herbs
# ...       ...             ...               ...                      ...
# 2779      914         Chicken      Animal foods
# 2780      914         Chicken      Animal foods
# 2781      914         Chicken      Animal foods
# 2782      914         Chicken      Animal foods
# 2783      914         Chicken      Animal foods
#
# [2784 rows x 11 columns]

# %%
joined_recipes.loc[joined_recipes['recipe_id'] == 75]
# Out:
#       recipe_id                 title  \
# 584          75  Tres Leches Pancakes
# 733          75  Tres Leches Pancakes
# 1020         75  Tres Leches Pancakes
# 1180         75  Tres Leches Pancakes
# 1356         75  Tres Leches Pancakes
# 1698         75  Tres Leches Pancakes
# 2146         75  Tres Leches Pancakes
# 2238         75  Tres Leches Pancakes
# 2328         75  Tres Leches Pancakes
#
#                                                     url  rating  reviews  \
# 584   https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 733   https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 1020  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 1180  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 1356  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 1698  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 2146  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 2238  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 2328  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
#
#           source                                 recipe_ingredients  food_id  \
# 584   allrecipes  Sauce      sweetened condensed milk     evapor...      147
# 733   allrecipes  Sauce      sweetened condensed milk     evapor...      194
# 1020  allrecipes  Sauce      sweetened condensed milk     evapor...      584
# 1180  allrecipes  Sauce      sweetened condensed milk     evapor...      631
# 1356  allrecipes  Sauce      sweetened condensed milk     evapor...      648
# 1698  allrecipes  Sauce      sweetened condensed milk     evapor...      662
# 2146  allrecipes  Sauce      sweetened condensed milk     evapor...      811
# 2238  allrecipes  Sauce      sweetened condensed milk     evapor...      855
# 2328  allrecipes  Sauce      sweetened condensed milk     evapor...      907
#
#       ingredient_name                   group            sub_group
# 584            Almond                    Nuts                 Nuts
# 733           Vanilla        Herbs and Spices               Spices
# 1020         Cinnamon        Herbs and Spices               Spices
# 1180             Eggs                    Eggs                 Eggs
# 1356             Cake         Confectioneries             Desserts
# 1698            Cream  Milk and milk products  Other milk products
# 2146  Evaporated milk  Milk and milk products  Other milk products
# 2238   Condensed milk  Milk and milk products  Other milk products
# 2328             Milk  Milk and milk products

# %%
top_ingredients = joined_recipes.ingredient_name.value_counts().reset_index()
top_ingredients.head(30)
# Out:
#    ingredient_name  count
# 0             Salt    199
# 1            Onion    140
# 2           Garlic    129
# 3           Butter    122
# 4            Sugar    105
# 5            Olive     87
# 6           Cheese     86
# 7        Olive Oil     80
# 8             Eggs     76
# 9             Milk     75
# 10          Cloves     73
# 11         Chicken     72
# 12           Cream     71
# 13           Flour     70
# 14            Beef     48
# 15         Parsley     46
# 16        Cinnamon     43
# 17         Vinegar     43
# 18           Lemon     41
# 19         Vanilla     40
# 20          Carrot     37
# 21            Rice     34
# 22           Bread     34
# 23         Mustard     30
# 24            Corn     30
# 25            Bean     28
# 26           Apple     24
# 27          Ginger     24
# 28       Soy sauce     23
# 29       Chocolate     22

# %% [markdown]
# ok so now i want to classify each recipe as vegetarian, or dairy free or neither. each recipe will appear for each ingredient it has matched on. how can i show all ingredients for each recipe? this feels like MAYBE a sql query? i think maybe a window function could do that??? or a loop?

# %% [markdown]
# for each recipe ID:

# %% [markdown]
# save olive oil DF as temp, then save a data frame that has olive oil as string, then use tilde to pull everything that ain't olive oil as a string. THOSE would be the olives and the other would be the olive OILS.
#
# singular olive = olive oil
# plural olives = olive as an ingredient!!!!
#
#
# for cloves: search 4 string 'cloves garlic'

# %%
olive_df = joined_recipes.loc[joined_recipes['ingredient_name'] == 'Olive']

# %%
just_olives = olive_df.loc[(olive_df['recipe_ingredients'].str.contains('olives')) & (~olive_df['recipe_ingredients'].str.contains('olive oil'))]

# %%
just_olives
# Out:
#      recipe_id                                              title  \
# 405         85                           Baked Breakfast Taquitos
# 409        131                                        Pasta Salad
# 415        162                          Quick Italian Pasta Salad
# 445        256  5 Ingredient Sauteed Chicken and Broccoli Rabe...
# 452        304                               7 Layer Sombrero Dip
# 461        341  5 Ingredient Sauteed Chicken and Broccoli Rabe...
# 468        389                               7 Layer Sombrero Dip
#
#                                                    url  rating  reviews  \
# 405  https://www.allrecipes.com/baked-breakfast-taq...     3.0      1.0
# 409  https://www.allrecipes.com/recipe/14385/pasta-...     4.6    321.0
# 415  https://www.allrecipes.com/recipe/222750/quick...     4.7    160.0
# 445  https://www.foodnetwork.com/recipes/robin-mill...     4.2     32.0
# 452  https://www.foodnetwork.com/recipes/7-layer-so...     4.5      0.0
# 461  https://www.foodnetwork.com/recipes/robin-mill...     4.2     32.0
# 468  https://www.foodnetwork.com/recipes/7-layer-so...     4.5      0.0
#
#            source                                 recipe_ingredients  food_id  \
# 405    allrecipes    vegetable oil     cremini mushrooms      red...      120
# 409    allrecipes    tri colored spiral pasta       bottle Italia...      120
# 415    allrecipes        tri color rotini pasta    Italian salami...      120
# 445  food network       oil packed sun dried tomatoes  plus   oil...      120
# 452  food network       monterey Jack cheese    shredded Cheddar ...      120
# 461  food network       oil packed sun dried tomatoes  plus   oil...      120
# 468  food network       monterey Jack cheese    shredded Cheddar ...      120
#
#     ingredient_name       group         sub_group
# 405           Olive  Vegetables  Fruit vegetables
# 409           Olive  Vegetables  Fruit vegetables
# 415           Olive  Vegetables  Fruit vegetables
# 445           Olive  Vegetables  Fruit vegetables
# 452           Olive  Vegetables  Fruit vegetables
# 461           Olive  Vegetables  Fruit vegetables
# 468           Olive  Vegetables  Fruit vegetables

# %%
olives_and_oil = olive_df.loc[(olive_df['recipe_ingredients'].str.contains('olives')) & (olive_df['recipe_ingredients'].str.contains('olive oil'))]

# %%
olives_and_oil['ingredient_name'] = 'Olive Oil'
olives_and_oil['food_id'] = 907
olives_and_oil['group'] = 'Herbs and spices'
olives_and_oil['sub_group'] = 'Oilseed crop'
# Out:
# C:\Users\rose\AppData\Local\Temp\ipykernel_59896\3140040164.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   olives_and_oil['ingredient_name'] = 'Olive Oil'
# C:\Users\rose\AppData\Local\Temp\ipykernel_59896\3140040164.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   olives_and_oil['food_id'] = 907
# C:\Users\rose\AppData\Local\Temp\ipykernel_59896\3140040164.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   olives_and_oil['group'] = 'Herbs and spices'
# C:\Users\rose\AppData\Local\Temp\ipykernel_59896\3140040164.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   olives_and_oil['sub_group'] = 'Oilseed crop'

# %%
olives_and_oil
# Out:
#      recipe_id                                              title  \
# 410        146                 Pasta Salad with Homemade Dressing
# 416        167               Eggplant Caponata (Sicilian Version)
# 426        189  "A Bologna" - Calamari, Scallops and Clams wit...
# 430        204                               A Burger for Rachael
# 431        205                               A Burger for Rachael
# 432        214                A Meaningful Beaning-Ful Bean Salad
# 434        216                        A Nice Italian Girl's Salad
# 437        227  A Stuffed Picnic: Tuna and Artichoke Stuffed T...
# 438        228                               A Trio of Bruschetta
# 453        308                             7-Layer Greek Meze Dip
# 469        393                             7-Layer Greek Meze Dip
#
#                                                    url  rating  reviews  \
# 410  https://www.allrecipes.com/recipe/73963/pasta-...     4.7    276.0
# 416  https://www.allrecipes.com/recipe/247268/eggpl...     4.9     88.0
# 426  https://www.foodnetwork.com/recipes/a-bologna-...     5.0      1.0
# 430  https://www.foodnetwork.com/recipes/rachael-ra...     4.3     30.0
# 431  https://www.foodnetwork.com/recipes/rachael-ra...     0.0      0.0
# 432  https://www.foodnetwork.com/recipes/a-meaningf...     5.0      1.0
# 434  https://www.foodnetwork.com/recipes/rachael-ra...     3.5     13.0
# 437  https://www.foodnetwork.com/recipes/rachael-ra...     4.1     48.0
# 438  https://www.foodnetwork.com/recipes/bobby-flay...     4.3      7.0
# 453  https://www.foodnetwork.com/recipes/food-netwo...     0.0      0.0
# 469  https://www.foodnetwork.com/recipes/food-netwo...     0.0      0.0
#
#            source                                 recipe_ingredients  food_id  \
# 410    allrecipes  Pasta Salad          tri color rotini pasta   ...      907
# 416    allrecipes    eggplant   cut into     cubes    salt    oli...      907
# 426  food network      fingerling potatoes  halved lengthwise   o...      907
# 430  food network      Idaho potatoes  scrubbed     extra virgin ...      907
# 431  food network      Idaho potatoes  scrubbed     extra virgin ...      907
# 432  food network       string beans  cut in half    chick peas  ...      907
# 434  food network     sack  romaine lettuce      special black pi...      907
# 437  food network      McIntosh apples  wedges lemon   butter  so...      907
# 438  food network      cooked white beans  if using ned  rinsed  ...      907
# 453  food network       bulgur Kosher salt   olive oil    eggplan...      907
# 469  food network       bulgur Kosher salt   olive oil    eggplan...      907
#
#     ingredient_name             group     sub_group
# 410       Olive Oil  Herbs and spices  Oilseed crop
# 416       Olive Oil  Herbs and spices  Oilseed crop
# 426       Olive Oil  Herbs and spices  Oilseed crop
# 430       Olive Oil  Herbs and spices  Oilseed crop
# 431       Olive Oil  Herbs and spices  Oilseed crop
# 432       Olive Oil  Herbs and spices  Oilseed crop
# 434       Olive Oil  Herbs and spices  Oilseed crop
# 437       Olive Oil  Herbs and spices  Oilseed crop
# 438       Olive Oil  Herbs and spices  Oilseed crop
# 453       Olive Oil  Herbs and spices  Oilseed crop
# 469       Olive Oil  Herbs and spices  Oilseed crop

# %%
just_olive_oil = olive_df.loc[(~olive_df['recipe_ingredients'].str.contains('olives')) & (olive_df['recipe_ingredients'].str.contains('olive oil'))]

# %%
just_olive_oil['ingredient_name'] = 'Olive Oil'
just_olive_oil['food_id'] = 907
just_olive_oil['group'] = 'Herbs and Spices'
just_olive_oil['sub_group'] = 'Oilseed crops'
# Out:
# C:\Users\rose\AppData\Local\Temp\ipykernel_59896\974287492.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   just_olive_oil['ingredient_name'] = 'Olive Oil'
# C:\Users\rose\AppData\Local\Temp\ipykernel_59896\974287492.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   just_olive_oil['food_id'] = 907
# C:\Users\rose\AppData\Local\Temp\ipykernel_59896\974287492.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   just_olive_oil['group'] = 'Herbs and Spices'
# C:\Users\rose\AppData\Local\Temp\ipykernel_59896\974287492.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   just_olive_oil['sub_group'] = 'Oilseed crops'

# %%
just_olive_oil
# Out:
#      recipe_id                                              title  \
# 387          1                Tex-Mex Pork Chops and Rice Skillet
# 388          8                                  Chicken Al Pastor
# 389         11  Prosciutto-Wrapped Pork Tenderloin with Crispy...
# 390         24                             Spaghetti Aglio e Olio
# 391         28                                  Roasted Pork Loin
# ..         ...                                                ...
# 467        388                         7 Fishes Fra Diavolo Pasta
# 470        396  7-Layer Salad with Pine Nut Pesto, Bacon and R...
# 471        403     8 Shots of Honey Bourbon BLT's, Please...on Me
# 472        404  8 Spiced Pot Roast with Roasted Vegetables and...
# 473        405  8 Spiced Pot Roast with Roasted Vegetables and...
#
#                                                    url  rating  reviews  \
# 387  https://www.allrecipes.com/tex-mex-pork-chops-...     4.9      8.0
# 388  https://www.allrecipes.com/recipe/8509102/chic...     4.4      7.0
# 389  https://www.allrecipes.com/recipe/245210/prosc...     4.6     14.0
# 390  https://www.allrecipes.com/recipe/222000/spagh...     4.7    477.0
# 391  https://www.allrecipes.com/recipe/21766/roaste...     4.5   1381.0
# ..                                                 ...     ...      ...
# 467  https://www.foodnetwork.com/recipes/food-netwo...     4.4      5.0
# 470  https://www.foodnetwork.com/recipes/7-layer-sa...     2.0      1.0
# 471  https://www.foodnetwork.com/recipes/jeff-mauro...     2.0      2.0
# 472  https://www.foodnetwork.com/recipes/8-spiced-p...     4.6      8.0
# 473  https://www.foodnetwork.com/recipes/8-spiced-p...     5.0      3.0
#
#            source                                 recipe_ingredients  food_id  \
# 387    allrecipes    olive oil   boneless pork chops            t...      907
# 388    allrecipes    dried guajillo chiles  stemmed seeded    ach...      907
# 389    allrecipes    pork tenderloin    salt ground black pepper ...      907
# 390    allrecipes     spaghetti    olive oil   cloves garlic  thi...      907
# 391    allrecipes   cloves garlic  minced    dried rosemary    sa...      907
# ..            ...                                                ...      ...
# 467  food network      extra virgin olive oil    panko   Kosher s...      907
# 470  food network      packed basil leaves  stems removed    Fish...      907
# 471  food network     Kentucky bourbon   olive oil   balsamic vin...      907
# 472  food network    One    boneless chuckrump roast Fleur de sel...      907
# 473  food network       boneless chuckrump roast Fleur de sel sea...      907
#
#     ingredient_name             group      sub_group
# 387       Olive Oil  Herbs and Spices  Oilseed crops
# 388       Olive Oil  Herbs and Spices  Oilseed crops
# 389       Olive Oil  Herbs and Spices  Oilseed crops
# 390       Olive Oil  Herbs and Spices  Oilseed crops
# 391       Olive Oil  Herbs and Spices  Oilseed crops
# ..              ...               ...            ...
# 467       Olive Oil  Herbs and Spices  Oilseed crops
# 470       Olive Oil  Herbs and Spices  Oilseed crops
# 471       Olive Oil  Herbs and Spices  Oilseed crops
# 472       Olive Oil  Herbs and Spices  Oilseed crops
# 473       Olive Oil  Herbs and Spices  Oilseed crops
#
# [69 rows x 11 columns]

# %%
query = '''
SELECT recipes.recipe_id, 
		title,  
		url, 
		rating, 
		reviews, 
		source, 
		recipes.ingredients AS recipe_ingredients, 
		gen_ing.food_id, 
		gen_ing.food_name AS ingredient_name,
        gen_ing.group,
        gen_ing.sub_group
FROM recipes
	INNER JOIN recipe_g_ingredients ON recipes.index = recipe_g_ingredients.recipe_id
	INNER JOIN gen_ing ON ingredient_id = food_id
WHERE food_id != 120
'''

with engine.connect() as connection:    
    joined_recipes_2 = pd.read_sql(text(query), con = connection)

# %%
joined_recipes_2
# Out:
#       recipe_id                                              title  \
# 0           220              A Potato Soup with Flaky Potato Knish
# 1             1                Tex-Mex Pork Chops and Rice Skillet
# 2             2                Spicy Canned Salmon Salad Rice Bowl
# 3             3                             Grilled Tomahawk Steak
# 4             4                                      Chicken Bhuna
# ...         ...                                                ...
# 2692        376        5-Spice Pork Stir Fry with Mandarin Oranges
# 2693        382  50/50 Olive Oil/Coconut Oil Blend Healthy Chic...
# 2694        385  6-Minute Egg on Creamy Polenta with Crispy Ser...
# 2695        406    8 Treasure Stuffed Turkey with Shiraz-Honey Jus
# 2696        407           9 Time Pro-Roller - Chicken Spring Rolls
#
#                                                     url  rating  reviews  \
# 0     https://www.foodnetwork.com/recipes/a-potato-s...     3.8      5.0
# 1     https://www.allrecipes.com/tex-mex-pork-chops-...     4.9      8.0
# 2     https://www.allrecipes.com/spicy-canned-salmon...     5.0      1.0
# 3     https://www.allrecipes.com/grilled-tomahawk-st...     4.5      4.0
# 4     https://www.allrecipes.com/chicken-bhuna-recip...     4.0      4.0
# ...                                                 ...     ...      ...
# 2692  https://www.foodnetwork.com/recipes/5-spice-po...     5.0      1.0
# 2693  https://www.foodnetwork.com/recipes/herb-mesa/...     4.3      4.0
# 2694  https://www.foodnetwork.com/recipes/6-minute-e...     0.0      0.0
# 2695  https://www.foodnetwork.com/recipes/8-treasure...     0.0      0.0
# 2696  https://www.foodnetwork.com/recipes/9-time-pro...     3.0      2.0
#
#             source                                 recipe_ingredients  \
# 0     food network       unsalted butter   onion  coarsely    leek...
# 1       allrecipes    olive oil   boneless pork chops            t...
# 2       allrecipes     English cucumber    low sodium soy sauce   ...
# 3       allrecipes  Steak Rub Steak     brown sugar    Montreal st...
# 4       allrecipes    vegetable oil    onions        salt   cloves...
# ...            ...                                                ...
# 2692  food network      peaches      brown sugar    ketchup    app...
# 2693  food network      oil blend     carrots   minced fresh garli...
# 2694  food network     slices Serrano ham  eggs  bunches kale   bu...
# 2695  food network    Canola oil    free range  andorganic turkey ...
# 2696  food network     stalks lemon grass     fish sauce   sugar  ...
#
#       food_id ingredient_name             group                sub_group
# 0           6            Leek        Vegetables  Onion-family vegetables
# 1           7          Garlic  Herbs and Spices                    Herbs
# 2           7          Garlic  Herbs and Spices                    Herbs
# 3           7          Garlic  Herbs and Spices                    Herbs
# 4           7          Garlic  Herbs and Spices                    Herbs
# ...       ...             ...               ...                      ...
# 2692      914         Chicken      Animal foods
# 2693      914         Chicken      Animal foods
# 2694      914         Chicken      Animal foods
# 2695      914         Chicken      Animal foods
# 2696      914         Chicken      Animal foods
#
# [2697 rows x 11 columns]

# %%
joined_recipes_2.loc[joined_recipes_2['recipe_id'] == 75]
# Out:
#       recipe_id                 title  \
# 497          75  Tres Leches Pancakes
# 646          75  Tres Leches Pancakes
# 933          75  Tres Leches Pancakes
# 1093         75  Tres Leches Pancakes
# 1269         75  Tres Leches Pancakes
# 1611         75  Tres Leches Pancakes
# 2059         75  Tres Leches Pancakes
# 2151         75  Tres Leches Pancakes
# 2241         75  Tres Leches Pancakes
#
#                                                     url  rating  reviews  \
# 497   https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 646   https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 933   https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 1093  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 1269  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 1611  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 2059  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 2151  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 2241  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
#
#           source                                 recipe_ingredients  food_id  \
# 497   allrecipes  Sauce      sweetened condensed milk     evapor...      147
# 646   allrecipes  Sauce      sweetened condensed milk     evapor...      194
# 933   allrecipes  Sauce      sweetened condensed milk     evapor...      584
# 1093  allrecipes  Sauce      sweetened condensed milk     evapor...      631
# 1269  allrecipes  Sauce      sweetened condensed milk     evapor...      648
# 1611  allrecipes  Sauce      sweetened condensed milk     evapor...      662
# 2059  allrecipes  Sauce      sweetened condensed milk     evapor...      811
# 2151  allrecipes  Sauce      sweetened condensed milk     evapor...      855
# 2241  allrecipes  Sauce      sweetened condensed milk     evapor...      907
#
#       ingredient_name                   group            sub_group
# 497            Almond                    Nuts                 Nuts
# 646           Vanilla        Herbs and Spices               Spices
# 933          Cinnamon        Herbs and Spices               Spices
# 1093             Eggs                    Eggs                 Eggs
# 1269             Cake         Confectioneries             Desserts
# 1611            Cream  Milk and milk products  Other milk products
# 2059  Evaporated milk  Milk and milk products  Other milk products
# 2151   Condensed milk  Milk and milk products  Other milk products
# 2241             Milk  Milk and milk products

# %%
joined_recipes = pd.concat([joined_recipes_2, just_olives, olives_and_oil, just_olive_oil])

# %%
len(joined_recipes)
# Out:
# 2784

# %%
joined_recipes.loc[joined_recipes['recipe_id'] == 75]
# Out:
#       recipe_id                 title  \
# 497          75  Tres Leches Pancakes
# 646          75  Tres Leches Pancakes
# 933          75  Tres Leches Pancakes
# 1093         75  Tres Leches Pancakes
# 1269         75  Tres Leches Pancakes
# 1611         75  Tres Leches Pancakes
# 2059         75  Tres Leches Pancakes
# 2151         75  Tres Leches Pancakes
# 2241         75  Tres Leches Pancakes
#
#                                                     url  rating  reviews  \
# 497   https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 646   https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 933   https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 1093  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 1269  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 1611  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 2059  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 2151  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 2241  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
#
#           source                                 recipe_ingredients  food_id  \
# 497   allrecipes  Sauce      sweetened condensed milk     evapor...      147
# 646   allrecipes  Sauce      sweetened condensed milk     evapor...      194
# 933   allrecipes  Sauce      sweetened condensed milk     evapor...      584
# 1093  allrecipes  Sauce      sweetened condensed milk     evapor...      631
# 1269  allrecipes  Sauce      sweetened condensed milk     evapor...      648
# 1611  allrecipes  Sauce      sweetened condensed milk     evapor...      662
# 2059  allrecipes  Sauce      sweetened condensed milk     evapor...      811
# 2151  allrecipes  Sauce      sweetened condensed milk     evapor...      855
# 2241  allrecipes  Sauce      sweetened condensed milk     evapor...      907
#
#       ingredient_name                   group            sub_group
# 497            Almond                    Nuts                 Nuts
# 646           Vanilla        Herbs and Spices               Spices
# 933          Cinnamon        Herbs and Spices               Spices
# 1093             Eggs                    Eggs                 Eggs
# 1269             Cake         Confectioneries             Desserts
# 1611            Cream  Milk and milk products  Other milk products
# 2059  Evaporated milk  Milk and milk products  Other milk products
# 2151   Condensed milk  Milk and milk products  Other milk products
# 2241             Milk  Milk and milk products

# %%
joined_recipes.drop_duplicates()
# Out:
#      recipe_id                                              title  \
# 0          220              A Potato Soup with Flaky Potato Knish
# 1            1                Tex-Mex Pork Chops and Rice Skillet
# 2            2                Spicy Canned Salmon Salad Rice Bowl
# 3            3                             Grilled Tomahawk Steak
# 4            4                                      Chicken Bhuna
# ..         ...                                                ...
# 467        388                         7 Fishes Fra Diavolo Pasta
# 470        396  7-Layer Salad with Pine Nut Pesto, Bacon and R...
# 471        403     8 Shots of Honey Bourbon BLT's, Please...on Me
# 472        404  8 Spiced Pot Roast with Roasted Vegetables and...
# 473        405  8 Spiced Pot Roast with Roasted Vegetables and...
#
#                                                    url  rating  reviews  \
# 0    https://www.foodnetwork.com/recipes/a-potato-s...     3.8      5.0
# 1    https://www.allrecipes.com/tex-mex-pork-chops-...     4.9      8.0
# 2    https://www.allrecipes.com/spicy-canned-salmon...     5.0      1.0
# 3    https://www.allrecipes.com/grilled-tomahawk-st...     4.5      4.0
# 4    https://www.allrecipes.com/chicken-bhuna-recip...     4.0      4.0
# ..                                                 ...     ...      ...
# 467  https://www.foodnetwork.com/recipes/food-netwo...     4.4      5.0
# 470  https://www.foodnetwork.com/recipes/7-layer-sa...     2.0      1.0
# 471  https://www.foodnetwork.com/recipes/jeff-mauro...     2.0      2.0
# 472  https://www.foodnetwork.com/recipes/8-spiced-p...     4.6      8.0
# 473  https://www.foodnetwork.com/recipes/8-spiced-p...     5.0      3.0
#
#            source                                 recipe_ingredients  food_id  \
# 0    food network       unsalted butter   onion  coarsely    leek...        6
# 1      allrecipes    olive oil   boneless pork chops            t...        7
# 2      allrecipes     English cucumber    low sodium soy sauce   ...        7
# 3      allrecipes  Steak Rub Steak     brown sugar    Montreal st...        7
# 4      allrecipes    vegetable oil    onions        salt   cloves...        7
# ..            ...                                                ...      ...
# 467  food network      extra virgin olive oil    panko   Kosher s...      907
# 470  food network      packed basil leaves  stems removed    Fish...      907
# 471  food network     Kentucky bourbon   olive oil   balsamic vin...      907
# 472  food network    One    boneless chuckrump roast Fleur de sel...      907
# 473  food network       boneless chuckrump roast Fleur de sel sea...      907
#
#     ingredient_name             group                sub_group
# 0              Leek        Vegetables  Onion-family vegetables
# 1            Garlic  Herbs and Spices                    Herbs
# 2            Garlic  Herbs and Spices                    Herbs
# 3            Garlic  Herbs and Spices                    Herbs
# 4            Garlic  Herbs and Spices                    Herbs
# ..              ...               ...                      ...
# 467       Olive Oil  Herbs and Spices            Oilseed crops
# 470       Olive Oil  Herbs and Spices            Oilseed crops
# 471       Olive Oil  Herbs and Spices            Oilseed crops
# 472       Olive Oil  Herbs and Spices            Oilseed crops
# 473       Olive Oil  Herbs and Spices            Oilseed crops
#
# [2784 rows x 11 columns]

# %% [markdown]
# NOW FOR GARLIC!

# %%
joined_recipes.loc[(joined_recipes['ingredient_name'] == 'Cloves') & (joined_recipes['recipe_ingredients'].str.contains('cloves garlic'))]
# Out:
#      recipe_id                                              title  \
# 566          1                Tex-Mex Pork Chops and Rice Skillet
# 567          4                                      Chicken Bhuna
# 568          6                                  Corned Beef Roast
# 569          7                          Stout-Braised Lamb Shanks
# 570          8                                  Chicken Al Pastor
# ..         ...                                                ...
# 634        400                      7-Spice Garlic BBQ Short Ribs
# 635        401                      7-Spice Garlic BBQ Short Ribs
# 636        404  8 Spiced Pot Roast with Roasted Vegetables and...
# 637        405  8 Spiced Pot Roast with Roasted Vegetables and...
# 638        407           9 Time Pro-Roller - Chicken Spring Rolls
#
#                                                    url  rating  reviews  \
# 566  https://www.allrecipes.com/tex-mex-pork-chops-...     4.9      8.0
# 567  https://www.allrecipes.com/chicken-bhuna-recip...     4.0      4.0
# 568  https://www.allrecipes.com/recipe/83646/corned...     4.4     68.0
# 569  https://www.allrecipes.com/recipe/158799/stout...     4.5     47.0
# 570  https://www.allrecipes.com/recipe/8509102/chic...     4.4      7.0
# ..                                                 ...     ...      ...
# 634  https://www.foodnetwork.com/recipes/7-spice-ga...     0.0      0.0
# 635  https://www.foodnetwork.com/recipes/7-spice-ga...     0.0      0.0
# 636  https://www.foodnetwork.com/recipes/8-spiced-p...     4.6      8.0
# 637  https://www.foodnetwork.com/recipes/8-spiced-p...     5.0      3.0
# 638  https://www.foodnetwork.com/recipes/9-time-pro...     3.0      2.0
#
#            source                                 recipe_ingredients  food_id  \
# 566    allrecipes    olive oil   boneless pork chops            t...      178
# 567    allrecipes    vegetable oil    onions        salt   cloves...      178
# 568    allrecipes         corned beef brisket with spice packet  ...      178
# 569    allrecipes    vegetable oil    lamb shanks    onion     cl...      178
# 570    allrecipes    dried guajillo chiles  stemmed seeded    ach...      178
# ..            ...                                                ...      ...
# 634  food network      vegetable oil  plus  if   cloves garlic  m...      178
# 635  food network      vegetable oil  plus  if   cloves garlic  m...      178
# 636  food network    One    boneless chuckrump roast Fleur de sel...      178
# 637  food network       boneless chuckrump roast Fleur de sel sea...      178
# 638  food network     stalks lemon grass     fish sauce   sugar  ...      178
#
#     ingredient_name             group sub_group
# 566          Cloves  Herbs and Spices    Spices
# 567          Cloves  Herbs and Spices    Spices
# 568          Cloves  Herbs and Spices    Spices
# 569          Cloves  Herbs and Spices    Spices
# 570          Cloves  Herbs and Spices    Spices
# ..              ...               ...       ...
# 634          Cloves  Herbs and Spices    Spices
# 635          Cloves  Herbs and Spices    Spices
# 636          Cloves  Herbs and Spices    Spices
# 637          Cloves  Herbs and Spices    Spices
# 638          Cloves  Herbs and Spices    Spices
#
# [67 rows x 11 columns]

# %%
# joined_recipes['ingredient_name'] = joined_recipes[['ingredient_name', 'recipe_ingredients']].apply(lambda x:'Garlic' if(x['ingredient_name'] == 'Cloves' and x['recipe_ingredients'].contains('cloves garlic')) else x['ingredient_name'])

# %%
joined_recipes.loc[joined_recipes['recipe_id'] == 75]
# Out:
#       recipe_id                 title  \
# 497          75  Tres Leches Pancakes
# 646          75  Tres Leches Pancakes
# 933          75  Tres Leches Pancakes
# 1093         75  Tres Leches Pancakes
# 1269         75  Tres Leches Pancakes
# 1611         75  Tres Leches Pancakes
# 2059         75  Tres Leches Pancakes
# 2151         75  Tres Leches Pancakes
# 2241         75  Tres Leches Pancakes
#
#                                                     url  rating  reviews  \
# 497   https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 646   https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 933   https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 1093  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 1269  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 1611  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 2059  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 2151  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
# 2241  https://www.allrecipes.com/tres-leches-pancake...     5.0      2.0
#
#           source                                 recipe_ingredients  food_id  \
# 497   allrecipes  Sauce      sweetened condensed milk     evapor...      147
# 646   allrecipes  Sauce      sweetened condensed milk     evapor...      194
# 933   allrecipes  Sauce      sweetened condensed milk     evapor...      584
# 1093  allrecipes  Sauce      sweetened condensed milk     evapor...      631
# 1269  allrecipes  Sauce      sweetened condensed milk     evapor...      648
# 1611  allrecipes  Sauce      sweetened condensed milk     evapor...      662
# 2059  allrecipes  Sauce      sweetened condensed milk     evapor...      811
# 2151  allrecipes  Sauce      sweetened condensed milk     evapor...      855
# 2241  allrecipes  Sauce      sweetened condensed milk     evapor...      907
#
#       ingredient_name                   group            sub_group
# 497            Almond                    Nuts                 Nuts
# 646           Vanilla        Herbs and Spices               Spices
# 933          Cinnamon        Herbs and Spices               Spices
# 1093             Eggs                    Eggs                 Eggs
# 1269             Cake         Confectioneries             Desserts
# 1611            Cream  Milk and milk products  Other milk products
# 2059  Evaporated milk  Milk and milk products  Other milk products
# 2151   Condensed milk  Milk and milk products  Other milk products
# 2241             Milk  Milk and milk products

# %% [markdown]
# WHAT I WANT TO DO! i want to DROP rows that have ingredient_name CLOVES but recipe_ingredients contains 'clove garlic

# %%
joined_recipes_test = joined_recipes[(~(joined_recipes['ingredient_name'] == 'Cloves') & (joined_recipes['recipe_ingredients'].str.contains('cloves garlic')))]

# %%
joined_recipes_test.loc[joined_recipes_test['ingredient_name'] == 'Eggs']
# Out:
#       recipe_id                                              title  \
# 1080         39                      Chef John's Italian Meatballs
# 1083         62                                 The Best Meatballs
# 1084         63             Chilaquiles with Homemade Tomato Sauce
# 1145        300  6-Minute Egg on Creamy Polenta with Crispy Ser...
# 1152        385  6-Minute Egg on Creamy Polenta with Crispy Ser...
#
#                                                     url  rating  reviews  \
# 1080  https://www.allrecipes.com/recipe/220854/chef-...     4.8   2346.0
# 1083  https://www.allrecipes.com/recipe/40399/the-be...     4.7   1625.0
# 1084  https://www.allrecipes.com/chilaquiles-with-ho...     NaN      NaN
# 1145  https://www.foodnetwork.com/recipes/6-minute-e...     0.0      0.0
# 1152  https://www.foodnetwork.com/recipes/6-minute-e...     0.0      0.0
#
#             source                                 recipe_ingredients  \
# 1080    allrecipes    plain bread crumbs    milk    olive oil    o...
# 1083    allrecipes    ground beef    ground veal    ground pork   ...
# 1084    allrecipes        corn tortillas    oil for frying    kosh...
# 1145  food network     slices Serrano ham  eggs  bunches kale   bu...
# 1152  food network     slices Serrano ham  eggs  bunches kale   bu...
#
#       food_id ingredient_name group sub_group
# 1080      631            Eggs  Eggs      Eggs
# 1083      631            Eggs  Eggs      Eggs
# 1084      631            Eggs  Eggs      Eggs
# 1145      631            Eggs  Eggs      Eggs
# 1152      631            Eggs  Eggs      Eggs

# %% [markdown]
# ^^ THIS IS WHERE I WENT WRONG!

# %%
# joined_recipes.to_csv('../data/joined_recipe2.csv')

# %%
joined_recipes_test = joined_recipes_test.drop_duplicates()

# %%
joined_recipes_test.loc[joined_recipes_test['recipe_id'] == 1]

# %%
joined_recipes_test.to_csv('../data/joined_recipe2.csv')

# %%
joined_recipes_test.loc[joined_recipes_test['ingredient_name'] == 'Pork']

# %%
joined_recipes_test['group'].value_counts()

# %%
joined_recipes_test['source'].value_counts()

# %%
joined_recipes_test.loc[joined_recipes_test['recipe_id'] == 75]
