# %%
import pandas as pd
from sqlalchemy import create_engine,text

# %%
database_name = 'capstone'
connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"
engine = create_engine(connection_string)

# %%
query = '''
SELECT recipes.recipe_id, 
		title,  
		url, 
		rating, 
		reviews, 
		source, 
		recipes.ingredients AS recipe_ingredients, 
		gen_ing.food_id, 
		gen_ing.food_name AS ingredient_name,
        gen_ing.group,
        gen_ing.sub_group
FROM recipes
	INNER JOIN recipe_g_ingredients ON recipes.index = recipe_g_ingredients.recipe_id
	INNER JOIN gen_ing ON ingredient_id = food_id
'''

with engine.connect() as connection:    
    joined_recipes = pd.read_sql(text(query), con = connection)

# %%
joined_recipes
# Out:
#       recipe_id                                   title  \
# 0           220   A Potato Soup with Flaky Potato Knish
# 1             1     Tex-Mex Pork Chops and Rice Skillet
# 2             2     Spicy Canned Salmon Salad Rice Bowl
# 3             3                  Grilled Tomahawk Steak
# 4             4                           Chicken Bhuna
# ...         ...                                     ...
# 1927        235               A.1. Orange Barbeque Ribs
# 1928        238  A.1. Sweet Fire Porterhouse Pork Chops
# 1929          7               Stout-Braised Lamb Shanks
# 1930         61                    Roasted Rack of Lamb
# 1931        234           A. N.'s Slow Shoulder of Lamb
#
#                                                     url  rating  reviews  \
# 0     https://www.foodnetwork.com/recipes/a-potato-s...     3.8      5.0
# 1     https://www.allrecipes.com/tex-mex-pork-chops-...     4.9      8.0
# 2     https://www.allrecipes.com/spicy-canned-salmon...     5.0      1.0
# 3     https://www.allrecipes.com/grilled-tomahawk-st...     4.5      4.0
# 4     https://www.allrecipes.com/chicken-bhuna-recip...     4.0      4.0
# ...                                                 ...     ...      ...
# 1927  https://www.foodnetwork.com/recipes/a1-orange-...     0.0      0.0
# 1928  https://www.foodnetwork.com/recipes/a1-sweet-f...     5.0      5.0
# 1929  https://www.allrecipes.com/recipe/158799/stout...     4.5     47.0
# 1930  https://www.allrecipes.com/recipe/45641/roaste...     4.8   1330.0
# 1931  https://www.foodnetwork.com/recipes/a-ns-slow-...     5.0      1.0
#
#             source                                 recipe_ingredients  \
# 0     food network       unsalted butter   onion  coarsely    leek...
# 1       allrecipes    olive oil   boneless pork chops            t...
# 2       allrecipes     English cucumber    low sodium soy sauce   ...
# 3       allrecipes  Steak Rub Steak     brown sugar    Montreal st...
# 4       allrecipes    vegetable oil    onions        salt   cloves...
# ...            ...                                                ...
# 1927  food network     lb  pork baby back ribs  Tbsp  brown sugar ...
# 1928  food network     Tbsp  oil   tsp  chipotle chile pepper powd...
# 1929    allrecipes    vegetable oil    lamb shanks    onion     cl...
# 1930    allrecipes    fresh bread crumbs    minced garlic     fres...
# 1931  food network     shoulder lamb       tins    haricots verts ...
#
#       food_id ingredient_name             group                sub_group
# 0           6            Leek        Vegetables  Onion-family vegetables
# 1           7          Garlic  Herbs and Spices                    Herbs
# 2           7          Garlic  Herbs and Spices                    Herbs
# 3           7          Garlic  Herbs and Spices                    Herbs
# 4           7          Garlic  Herbs and Spices                    Herbs
# ...       ...             ...               ...                      ...
# 1927      911            Pork      Animal foods
# 1928      911            Pork      Animal foods
# 1929      912            Lamb      Animal foods
# 1930      912            Lamb      Animal foods
# 1931      912            Lamb      Animal foods
#
# [1932 rows x 11 columns]

# %%
top_ingredients = joined_recipes.ingredient_name.value_counts().reset_index()
top_ingredients.head(30)
# Out:
#    ingredient_name  count
# 0             Salt    147
# 1            Onion     98
# 2           Butter     89
# 3           Garlic     75
# 4           Cheese     69
# 5             Eggs     63
# 6            Sugar     62
# 7            Flour     56
# 8            Olive     55
# 9             Milk     54
# 10           Water     46
# 11          Cloves     38
# 12           Sauce     36
# 13           Cream     36
# 14            Beef     34
# 15           Bread     33
# 16         Parsley     33
# 17             Rum     29
# 18             Gin     29
# 19         Vanilla     28
# 20         Vinegar     26
# 21        Cinnamon     25
# 22            Corn     25
# 23          Potato     23
# 24           Lemon     22
# 25         Mustard     22
# 26          Carrot     21
# 27            Rice     18
# 28             Pie     17
# 29             pea     16
