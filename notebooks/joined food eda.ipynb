# %%
import pandas as pd
from sqlalchemy import create_engine,text

# %%
database_name = 'capstone'
connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"
engine = create_engine(connection_string)

# %%
query = '''
SELECT recipes.recipe_id, 
		title,  
		url, 
		rating, 
		reviews, 
		source, 
		recipes.ingredients AS recipe_ingredients, 
		gen_ing.food_id, 
		gen_ing.food_name AS ingredient_name,
        gen_ing.group,
        gen_ing.sub_group
FROM recipes
	INNER JOIN recipe_g_ingredients ON recipes.index = recipe_g_ingredients.recipe_id
	INNER JOIN gen_ing ON ingredient_id = food_id
'''

with engine.connect() as connection:    
    joined_recipes = pd.read_sql(text(query), con = connection)

# %%
joined_recipes
# Out:
#       recipe_id                                              title  \
# 0           220              A Potato Soup with Flaky Potato Knish
# 1             1                Tex-Mex Pork Chops and Rice Skillet
# 2             2                Spicy Canned Salmon Salad Rice Bowl
# 3             3                             Grilled Tomahawk Steak
# 4             4                                      Chicken Bhuna
# ...         ...                                                ...
# 2448        393                             7-Layer Greek Meze Dip
# 2449        396  7-Layer Salad with Pine Nut Pesto, Bacon and R...
# 2450        403     8 Shots of Honey Bourbon BLT's, Please...on Me
# 2451        404  8 Spiced Pot Roast with Roasted Vegetables and...
# 2452        405  8 Spiced Pot Roast with Roasted Vegetables and...
#
#                                                     url  rating  reviews  \
# 0     https://www.foodnetwork.com/recipes/a-potato-s...     3.8      5.0
# 1     https://www.allrecipes.com/tex-mex-pork-chops-...     4.9      8.0
# 2     https://www.allrecipes.com/spicy-canned-salmon...     5.0      1.0
# 3     https://www.allrecipes.com/grilled-tomahawk-st...     4.5      4.0
# 4     https://www.allrecipes.com/chicken-bhuna-recip...     4.0      4.0
# ...                                                 ...     ...      ...
# 2448  https://www.foodnetwork.com/recipes/food-netwo...     0.0      0.0
# 2449  https://www.foodnetwork.com/recipes/7-layer-sa...     2.0      1.0
# 2450  https://www.foodnetwork.com/recipes/jeff-mauro...     2.0      2.0
# 2451  https://www.foodnetwork.com/recipes/8-spiced-p...     4.6      8.0
# 2452  https://www.foodnetwork.com/recipes/8-spiced-p...     5.0      3.0
#
#             source                                 recipe_ingredients  \
# 0     food network       unsalted butter   onion  coarsely    leek...
# 1       allrecipes    olive oil   boneless pork chops            t...
# 2       allrecipes     English cucumber    low sodium soy sauce   ...
# 3       allrecipes  Steak Rub Steak     brown sugar    Montreal st...
# 4       allrecipes    vegetable oil    onions        salt   cloves...
# ...            ...                                                ...
# 2448  food network       bulgur Kosher salt   olive oil    eggplan...
# 2449  food network      packed basil leaves  stems removed    Fish...
# 2450  food network     Kentucky bourbon   olive oil   balsamic vin...
# 2451  food network    One    boneless chuckrump roast Fleur de sel...
# 2452  food network       boneless chuckrump roast Fleur de sel sea...
#
#       food_id ingredient_name             group                sub_group
# 0           6            Leek        Vegetables  Onion-family vegetables
# 1           7          Garlic  Herbs and Spices                    Herbs
# 2           7          Garlic  Herbs and Spices                    Herbs
# 3           7          Garlic  Herbs and Spices                    Herbs
# 4           7          Garlic  Herbs and Spices                    Herbs
# ...       ...             ...               ...                      ...
# 2448      907       Olive Oil  Herbs and Spices            Oilseed crops
# 2449      907       Olive Oil  Herbs and Spices            Oilseed crops
# 2450      907       Olive Oil  Herbs and Spices            Oilseed crops
# 2451      907       Olive Oil  Herbs and Spices            Oilseed crops
# 2452      907       Olive Oil  Herbs and Spices            Oilseed crops
#
# [2453 rows x 11 columns]

# %%
top_ingredients = joined_recipes.ingredient_name.value_counts().reset_index()
top_ingredients.head(30)
# Out:
#    ingredient_name  count
# 0             Salt    199
# 1           Garlic    129
# 2           Butter    122
# 3            Sugar    105
# 4            Olive     87
# 5           Cheese     86
# 6        Olive Oil     80
# 7             Eggs     76
# 8           Cloves     73
# 9            Cream     71
# 10           Flour     70
# 11           Water     61
# 12         Parsley     46
# 13         Vinegar     43
# 14        Cinnamon     43
# 15           Lemon     41
# 16         Vanilla     40
# 17          Carrot     37
# 18            Rice     34
# 19            Corn     30
# 20         Mustard     30
# 21            Bean     28
# 22          Ginger     24
# 23           Apple     24
# 24       Soy sauce     23
# 25       Chocolate     22
# 26           Syrup     21
# 27           Cumin     21
# 28           Chili     20
# 29         Sausage     20

# %% [markdown]
# ok so now i want to classify each recipe as vegetarian, or dairy free or neither. each recipe will appear for each ingredient it has matched on. how can i show all ingredients for each recipe? this feels like MAYBE a sql query? i think maybe a window function could do that??? or a loop?

# %% [markdown]
# for each recipe ID:

# %% [markdown]
# save olive oil DF as temp, then save a data frame that has olive oil as string, then use tilde to pull everything that ain't olive oil as a string. THOSE would be the olives and the other would be the olive OILS.
#
# singular olive = olive oil
# plural olives = olive as an ingredient!!!!
#
#
# for cloves: search 4 string 'cloves garlic'

# %%
olive_df = joined_recipes.loc[joined_recipes['ingredient_name'] == 'Olive']

# %%
olive_df.loc[olive_df['recipe_ingredients'].str.contains('olives')]
# Out:
#      recipe_id                                              title  \
# 405         85                           Baked Breakfast Taquitos
# 409        131                                        Pasta Salad
# 410        146                 Pasta Salad with Homemade Dressing
# 415        162                          Quick Italian Pasta Salad
# 416        167               Eggplant Caponata (Sicilian Version)
# 426        189  "A Bologna" - Calamari, Scallops and Clams wit...
# 430        204                               A Burger for Rachael
# 431        205                               A Burger for Rachael
# 432        214                A Meaningful Beaning-Ful Bean Salad
# 434        216                        A Nice Italian Girl's Salad
# 437        227  A Stuffed Picnic: Tuna and Artichoke Stuffed T...
# 438        228                               A Trio of Bruschetta
# 445        256  5 Ingredient Sauteed Chicken and Broccoli Rabe...
# 452        304                               7 Layer Sombrero Dip
# 453        308                             7-Layer Greek Meze Dip
# 461        341  5 Ingredient Sauteed Chicken and Broccoli Rabe...
# 468        389                               7 Layer Sombrero Dip
# 469        393                             7-Layer Greek Meze Dip
#
#                                                    url  rating  reviews  \
# 405  https://www.allrecipes.com/baked-breakfast-taq...     3.0      1.0
# 409  https://www.allrecipes.com/recipe/14385/pasta-...     4.6    321.0
# 410  https://www.allrecipes.com/recipe/73963/pasta-...     4.7    276.0
# 415  https://www.allrecipes.com/recipe/222750/quick...     4.7    160.0
# 416  https://www.allrecipes.com/recipe/247268/eggpl...     4.9     88.0
# 426  https://www.foodnetwork.com/recipes/a-bologna-...     5.0      1.0
# 430  https://www.foodnetwork.com/recipes/rachael-ra...     4.3     30.0
# 431  https://www.foodnetwork.com/recipes/rachael-ra...     0.0      0.0
# 432  https://www.foodnetwork.com/recipes/a-meaningf...     5.0      1.0
# 434  https://www.foodnetwork.com/recipes/rachael-ra...     3.5     13.0
# 437  https://www.foodnetwork.com/recipes/rachael-ra...     4.1     48.0
# 438  https://www.foodnetwork.com/recipes/bobby-flay...     4.3      7.0
# 445  https://www.foodnetwork.com/recipes/robin-mill...     4.2     32.0
# 452  https://www.foodnetwork.com/recipes/7-layer-so...     4.5      0.0
# 453  https://www.foodnetwork.com/recipes/food-netwo...     0.0      0.0
# 461  https://www.foodnetwork.com/recipes/robin-mill...     4.2     32.0
# 468  https://www.foodnetwork.com/recipes/7-layer-so...     4.5      0.0
# 469  https://www.foodnetwork.com/recipes/food-netwo...     0.0      0.0
#
#            source                                 recipe_ingredients  food_id  \
# 405    allrecipes    vegetable oil     cremini mushrooms      red...      120
# 409    allrecipes    tri colored spiral pasta       bottle Italia...      120
# 410    allrecipes  Pasta Salad          tri color rotini pasta   ...      120
# 415    allrecipes        tri color rotini pasta    Italian salami...      120
# 416    allrecipes    eggplant   cut into     cubes    salt    oli...      120
# 426  food network      fingerling potatoes  halved lengthwise   o...      120
# 430  food network      Idaho potatoes  scrubbed     extra virgin ...      120
# 431  food network      Idaho potatoes  scrubbed     extra virgin ...      120
# 432  food network       string beans  cut in half    chick peas  ...      120
# 434  food network     sack  romaine lettuce      special black pi...      120
# 437  food network      McIntosh apples  wedges lemon   butter  so...      120
# 438  food network      cooked white beans  if using ned  rinsed  ...      120
# 445  food network       oil packed sun dried tomatoes  plus   oil...      120
# 452  food network       monterey Jack cheese    shredded Cheddar ...      120
# 453  food network       bulgur Kosher salt   olive oil    eggplan...      120
# 461  food network       oil packed sun dried tomatoes  plus   oil...      120
# 468  food network       monterey Jack cheese    shredded Cheddar ...      120
# 469  food network       bulgur Kosher salt   olive oil    eggplan...      120
#
#     ingredient_name       group         sub_group
# 405           Olive  Vegetables  Fruit vegetables
# 409           Olive  Vegetables  Fruit vegetables
# 410           Olive  Vegetables  Fruit vegetables
# 415           Olive  Vegetables  Fruit vegetables
# 416           Olive  Vegetables  Fruit vegetables
# 426           Olive  Vegetables  Fruit vegetables
# 430           Olive  Vegetables  Fruit vegetables
# 431           Olive  Vegetables  Fruit vegetables
# 432           Olive  Vegetables  Fruit vegetables
# 434           Olive  Vegetables  Fruit vegetables
# 437           Olive  Vegetables  Fruit vegetables
# 438           Olive  Vegetables  Fruit vegetables
# 445           Olive  Vegetables  Fruit vegetables
# 452           Olive  Vegetables  Fruit vegetables
# 453           Olive  Vegetables  Fruit vegetables
# 461           Olive  Vegetables  Fruit vegetables
# 468           Olive  Vegetables  Fruit vegetables
# 469           Olive  Vegetables  Fruit vegetables

# %%
# joined_recipes.to_csv('../data/joined_recipe2.csv')
