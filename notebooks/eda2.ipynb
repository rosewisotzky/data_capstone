# %%
import pandas as pd
import requests 
from bs4 import BeautifulSoup as BS

# %%
pd.set_option('display.max_columns', None)

# %%
ufo_df = pd.read_csv('../data/scrubbed.csv')
# Out:
# C:\Users\rose\AppData\Local\Temp\ipykernel_19252\4135395272.py:1: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   ufo_df = pd.read_csv('../data/scrubbed.csv')

# %%
ufo_df
# Out:
#                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration (seconds) duration (hours/min)  \
# 0                   2700           45 minutes
# ...

# %%
len(ufo_df.loc[ufo_df['state'] == 'nc'])
# Out:
# 1869

# %%
URL = 'https://www.greatschools.org/north-carolina/raleigh/schools/?distance=5&gradeLevels%5B%5D=e&gradeLevels%5B%5D=m&gradeLevels%5B%5D=h&lat=35.826&locationType=city&lon=-78.641&view=table'
response = requests.get(URL)
soup = BS(response.text)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://ogp.me/ns/fb#">
#  <head>
#   <title>
#    Raleigh Elementary Schools, 1-25 - Raleigh, NC | GreatSchools
#   </title>
#   <meta content="View and map all Raleigh, NC schools. Plus, compare or save schools" name="description"/>
#   <link href="https://www.greatschools.org/north-carolina/raleigh/schools/?gradeLevels%5B%5D=e&amp;gradeLevels%5B%5D=m&amp;gradeLevels%5B%5D=h" rel="canonical"/>
#   <link href="https://www.greatschools.org/north-carolina/raleigh/schools/?gradeLevels%5B%5D=e&amp;gradeLevels%5B%5D=m&amp;gradeLevels%5B%5D=h" hreflang="en" rel="alternate"/>
#   <link href="https://www.greatschools.org/north-carolina/raleigh/schools/?gradeLevels%5B%5D=e&amp;gradeLevels%5B%5D=m&amp;gradeLevels%5B%5D=h&amp;lang=es" hreflang="es" rel="alternate"/>
# ...

# %%
walkability = pd.read_csv('../data/walkability_index.csv')

# %%
walkability
# Out:
#         OBJECTID       GEOID10       GEOID20  STATEFP  COUNTYFP  TRACTCE  \
# 0              1  4.811300e+11  4.811300e+11       48       113     7825
# 1              2  4.811300e+11  4.811300e+11       48       113     7825
# 2              3  4.811300e+11  4.811300e+11       48       113     7825
# 3              4  4.811300e+11  4.811300e+11       48       113     7824
# 4              5  4.811300e+11  4.811300e+11       48       113     7824
# ...          ...           ...           ...      ...       ...      ...
# 220735    220736  7.803100e+11  7.803100e+11       78        30   961000
# 220736    220737  7.803100e+11  7.803100e+11       78        30   961000
# 220737    220738  7.803100e+11  7.803100e+11       78        30   961000
# 220738    220739  7.803100e+11  7.803100e+11       78        30   960700
# 220739    220740  7.803100e+11  7.803100e+11       78        30   960200
#
#         BLKGRPCE    CSA                  CSA_Name     CBSA  \
# ...

# %%
walk_index_only = walkability[['OBJECTID', 'STATEFP', 'COUNTYFP', 'CBSA_Name', 'CBSA', 'CBSA_Name', 'CBSA_POP', 'NatWalkInd']]

# %%
nash_walk = walk_index_only.loc[walk_index_only['CBSA'] == 34980.0]

# %%
nash_walk
# Out:
#         OBJECTID  STATEFP  COUNTYFP  \
# 200131    200132       47       111
# 200135    200136       47       119
# 200144    200145       47       119
# 200145    200146       47       119
# 200146    200147       47       119
# ...          ...      ...       ...
# 204223    204224       47       187
# 204231    204232       47        37
# 204232    204233       47        37
# 204233    204234       47        37
# 204234    204235       47        37
#
#                                              CBSA_Name     CBSA  \
# 200131  Nashville-Davidson--Murfreesboro--Franklin, TN  34980.0
# 200135  Nashville-Davidson--Murfreesboro--Franklin, TN  34980.0
# 200144  Nashville-Davidson--Murfreesboro--Franklin, TN  34980.0
# 200145  Nashville-Davidson--Murfreesboro--Franklin, TN  34980.0
# 200146  Nashville-Davidson--Murfreesboro--Franklin, TN  34980.0
# ...                                                ...      ...
# 204223  Nashville-Davidson--Murfreesboro--Franklin, TN  34980.0
# ...

# %%
zillow = pd.read_csv('../data/zillow_median.csv')

# %%
zillow
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  2018-03-31  \
# 0      102001         0    United States    country       NaN    263267.0
# 1      394913         1     New York, NY        msa        NY    503000.0
# 2      753899         2  Los Angeles, CA        msa        CA    721333.0
# 3      394463         3      Chicago, IL        msa        IL    284600.0
# 4      394514         4       Dallas, TX        msa        TX    322997.0
# ..        ...       ...              ...        ...       ...         ...
# 923    753929       935       Zapata, TX        msa        TX         NaN
# 924    394743       936    Ketchikan, AK        msa        AK    284500.0
# 925    753874       937        Craig, CO        msa        CO    192833.0
# 926    395188       938       Vernon, TX        msa        TX         NaN
# 927    394767       939       Lamesa, TX        msa        TX     96800.0
#
#      2018-04-30  2018-05-31  2018-06-30  2018-07-31  2018-08-31  2018-09-30  \
# ...

# %%
zillow.loc[zillow['RegionName'] == 'Nashville, TN']
# Out:
#     RegionID  SizeRank     RegionName RegionType StateName  2018-03-31  \
# 36    394902        37  Nashville, TN        msa        TN    327633.0
#
#     2018-04-30  2018-05-31  2018-06-30  2018-07-31  2018-08-31  2018-09-30  \
# 36    332933.0    334933.0    336600.0    333267.0    328267.0    324933.0
#
#     2018-10-31  2018-11-30  2018-12-31  2019-01-31  2019-02-28  2019-03-31  \
# 36    322467.0    322466.0    320800.0    318783.0    319450.0    321209.0
#
#     2019-04-30  2019-05-31  2019-06-30  2019-07-31  2019-08-31  2019-09-30  \
# 36    327392.0    333059.0    337967.0    337933.0    334900.0    331433.0
#
#     2019-10-31  2019-11-30  2019-12-31  2020-01-31  2020-02-29  2020-03-31  \
# 36    329767.0    328133.0    326633.0    323333.0    324000.0    327000.0
#
#     2020-04-30  2020-05-31  2020-06-30  2020-07-31  2020-08-31  2020-09-30  \
# 36    333500.0    339500.0    344833.0    348333.0    351633.0    351633.0
#
# ...
