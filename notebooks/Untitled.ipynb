# %%
import requests
from bs4 import BeautifulSoup as BS
import pandas as pd
import re
import time

# %%
URL = 'https://www.foodnetwork.com/recipes/recipes-a-z/a'
response = requests.get(URL)
soup = BS(response.text)
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <!-- /apps/sni-foundation/components/pages/basePage/pageCSSinclude.jsp -->
#   <!-- perftest_asyncCSS: 0 -->
#   <link href="//food.fnr.sndimg.com" rel="preconnect"/>
#   <link as="style" href="//food.fnr.sndimg.com/etc/clientlibs/assets/v2/css/food-desktop-include-fonts-rest.md5-4a50c915e9dbf9c54311c76f182ea08c.css" rel="preload"/>
#   <!-- critical styles -->
#   <style data-sni-css-critical="" type="text/css">
#    @charset "UTF-8";
#
# ...

# %%
link_items = soup.findAll('li', attrs={'class':'m-PromoList__a-ListItem'})

# %%
a_items = [x.find('a') for x in link_items]

# %%
a_items
# Out:
# [<a href="//www.foodnetwork.com/recipes/a-bologna-calamari-scallops-and-clams-with-roasted-fingerlings-and-arugula-salad-recipe-2040576">"A Bologna" - Calamari, Scallops and Clams with Roasted Fingerlings and Arugula Salad</a>,
#  <a href="//www.foodnetwork.com/recipes/jeff-mauro/a-piece-of-turkey-easy-roasted-thanksgiving-turkey-3170836">"A Piece of Turkey" Easy Roasted Thanksgiving Turkey</a>,
#  <a href="//www.foodnetwork.com/recipes/a-star-is-born-cupcakes-recipe-2017694">"A Star is Born" Cupcakes</a>,
#  <a href="//www.foodnetwork.com/recipes/aarti-party-aka-savory-sling-recipe-1924818">"Aarti Party" aka Savory Sling</a>,
#  <a href="//www.foodnetwork.com/recipes/acqua-pazza-with-sea-bass-and-clams-recipe-1910802">"Acqua Pazza" with Sea Bass and Clams</a>,
#  <a href="//www.foodnetwork.com/recipes/all-crabmeat-crab-cakes-1926139">"All Crabmeat" Crab Cakes</a>,
# ...

# %%
a_links = [x['href'] for x in a_items]

# %%
links = []
for link in a_links:
    new_link = 'https:' + link
    links.append(new_link)

# %%
links
# Out:
# ['https://www.foodnetwork.com/recipes/a-bologna-calamari-scallops-and-clams-with-roasted-fingerlings-and-arugula-salad-recipe-2040576',
#  'https://www.foodnetwork.com/recipes/jeff-mauro/a-piece-of-turkey-easy-roasted-thanksgiving-turkey-3170836',
#  'https://www.foodnetwork.com/recipes/a-star-is-born-cupcakes-recipe-2017694',
#  'https://www.foodnetwork.com/recipes/aarti-party-aka-savory-sling-recipe-1924818',
#  'https://www.foodnetwork.com/recipes/acqua-pazza-with-sea-bass-and-clams-recipe-1910802',
#  'https://www.foodnetwork.com/recipes/all-crabmeat-crab-cakes-1926139',
#  'https://www.foodnetwork.com/recipes/michael-symon/almost-famous-corn-pudding-9485040',
#  'https://www.foodnetwork.com/recipes/almost-famous-strawberry-lemonade-3364127',
#  'https://www.foodnetwork.com/recipes/ayuh-seafood-paella-recipe-1939810',
#  'https://www.foodnetwork.com/recipes/a-great-pye-recipe-1955265',
# ...

# %%
URL = 'https://www.foodnetwork.com/recipes/a-bologna-calamari-scallops-and-clams-with-roasted-fingerlings-and-arugula-salad-recipe-2040576' 
response = requests.get(URL)
time.sleep(10)
soup = BS(response.text)
soup.findAll('span', attrs={'class':'o-Ingredients__a-Ingredient--CheckboxLabel'})
# Out:
# [<span class="o-Ingredients__a-Ingredient--CheckboxLabel">Deselect All</span>,
#  <span class="o-Ingredients__a-Ingredient--CheckboxLabel">2 pounds fingerling potatoes, halved lengthwise</span>,
#  <span class="o-Ingredients__a-Ingredient--CheckboxLabel">7 tablespoons olive oil, divided</span>,
#  <span class="o-Ingredients__a-Ingredient--CheckboxLabel">Salt and freshly ground black pepper</span>,
#  <span class="o-Ingredients__a-Ingredient--CheckboxLabel">1/2 bottle Riesling wine</span>,
#  <span class="o-Ingredients__a-Ingredient--CheckboxLabel">2 shallots, minced</span>,
#  <span class="o-Ingredients__a-Ingredient--CheckboxLabel">1 pint heavy cream</span>,
#  <span class="o-Ingredients__a-Ingredient--CheckboxLabel">20 manilla clams</span>,
#  <span class="o-Ingredients__a-Ingredient--CheckboxLabel">2 tablespoons butter</span>,
#  <span class="o-Ingredients__a-Ingredient--CheckboxLabel">1 small bunch fresh chives, minced</span>,
# ...

# %%
soup.findAll('div', attrs={'class':'review reviewSummary'})
# Out:
# [<div class="review reviewSummary"><span class="clicktracking" data-resource-type="foodcom/components/hidden/reviewSummary" style="display: none"></span>
#  <div class="o-ReviewSummary" data-module="user/rating-summary">
#  <script type="text/x-config">
#    {
#      "chitterProxyEndpoint": "https://api.sni.foodnetwork.com/moderation-chitter-proxy/v1/",
#      "mode": "page-top",
#      "link": "#reviewsTop",
#      "assetId": "6900b148-0c2e-44eb-8220-0585508fadf7",
#      "assetType": "recipe"
#    }
#    </script>
#  <div class="review-summary">
#  <div class="rating-stars" title="loading">
#  <div class="rating-star rating-star-empty"></div><div class="rating-star rating-star-empty"></div><div class="rating-star rating-star-empty"></div><div class="rating-star rating-star-empty"></div><div class="rating-star rating-star-empty"></div>
#  </div>
#  <span class="loading">Getting reviews...</span>
#  </div>
#  </div>
#  </div>]
