# %%
import pandas as pd

# %%
walk_df = pd.read_csv('../data/walkability_index.csv')

# %%
davidson_walk = walk_df.loc[walk_df['CBSA'] == 34980.0]

# %%
davidson_walk
# Out:
#         OBJECTID       GEOID10       GEOID20  STATEFP  COUNTYFP  TRACTCE  \
# 200131    200132  4.711200e+11  4.711200e+11       47       111   970200
# 200135    200136  4.711900e+11  4.711900e+11       47       119    11102
# 200144    200145  4.711900e+11  4.711900e+11       47       119    10700
# 200145    200146  4.711900e+11  4.711900e+11       47       119    10700
# 200146    200147  4.711900e+11  4.711900e+11       47       119    11002
# ...          ...           ...           ...      ...       ...      ...
# 204223    204224  4.718710e+11  4.718710e+11       47       187    50403
# 204231    204232  4.703700e+11  4.703700e+11       47        37    10401
# 204232    204233  4.703700e+11  4.703700e+11       47        37    10401
# 204233    204234  4.703700e+11  4.703700e+11       47        37    10402
# 204234    204235  4.703700e+11  4.703700e+11       47        37    10402
#
#         BLKGRPCE    CSA                              CSA_Name     CBSA  ...  \
# ...

# %%
assessment_df = pd.read_csv('../data/school_assessment.csv')

# %%
assessment_df
# Out:
#         year  system                                 system_name  school  \
# 0       2022      10                             Anderson County       2
# 1       2022      10                             Anderson County       2
# 2       2022      10                             Anderson County       2
# 3       2022      10                             Anderson County       2
# 4       2022      10                             Anderson County       2
# ...      ...     ...                                         ...     ...
# 675529  2022     987  Tennessee Public Charter School Commission    8030
# 675530  2022     987  Tennessee Public Charter School Commission    8030
# 675531  2022     987  Tennessee Public Charter School Commission    8030
# 675532  2022     987  Tennessee Public Charter School Commission    8030
# 675533  2022     987  Tennessee Public Charter School Commission    8030
#
#                         school_name     test    subject       grade  \
# ...

# %%
davidson_schools = assessment_df.loc[assessment_df['system_name'] == 'Davidson County']

# %%
len(davidson_schools)
# Out:
# 57450

# %%
davidson_schools.describe()
# Out:
#           year   system        school      enrolled        tested  \
# count  57450.0  57450.0  57450.000000  57450.000000  57450.000000
# mean    2022.0    190.0   1962.471802     45.280940     43.281497
# std        0.0      0.0   3116.318916     76.267506     72.725147
# min     2022.0    190.0      1.000000      0.000000      0.000000
# 25%     2022.0    190.0    255.000000      2.000000      2.000000
# 50%     2022.0    190.0    456.000000     13.000000     12.000000
# 75%     2022.0    190.0    704.000000     60.000000     57.000000
# max     2022.0    190.0   8105.000000    851.000000    822.000000
#
#         valid_tests
# count  57450.000000
# mean      41.756658
# std       69.850587
# min        0.000000
# 25%        2.000000
# 50%       12.000000
# 75%       56.000000
# max      792.000000

# %%
davidson_schools.loc[davidson_schools['n_below'] != '*']
# Out:
#         year  system      system_name  school              school_name  \
# 86835   2022     190  Davidson County       1  A. Z. Kelley Elementary
# 86836   2022     190  Davidson County       1  A. Z. Kelley Elementary
# 86837   2022     190  Davidson County       1  A. Z. Kelley Elementary
# 86838   2022     190  Davidson County       1  A. Z. Kelley Elementary
# 86839   2022     190  Davidson County       1  A. Z. Kelley Elementary
# ...      ...     ...              ...     ...                      ...
# 144195  2022     190  Davidson County    8105       KA @ The Crossings
# 144196  2022     190  Davidson County    8105       KA @ The Crossings
# 144197  2022     190  Davidson County    8105       KA @ The Crossings
# 144199  2022     190  Davidson County    8105       KA @ The Crossings
# 144200  2022     190  Davidson County    8105       KA @ The Crossings
#
#            test         subject       grade  \
# 86835   TNReady             ELA           3
# ...

# %%
davidson_schools['test'].value_counts()
# Out:
# test
# TNReady                            30455
# MSAA/Alt-Science/Social Studies    13716
# EOC                                13279
# Name: count, dtype: int64

# %%
tn_walk = walk_df.loc[walk_df['STATEFP'] == 47]

# %%
tn_walk
# Out:
#         OBJECTID       GEOID10       GEOID20  STATEFP  COUNTYFP  TRACTCE  \
# 200128    200129  4.712510e+11  4.712510e+11       47       125   100100
# 200129    200130  4.712510e+11  4.712510e+11       47       125   100200
# 200130    200131  4.712510e+11  4.712510e+11       47       125   100200
# 200131    200132  4.711200e+11  4.711200e+11       47       111   970200
# 200132    200133  4.712510e+11  4.712510e+11       47       125   100300
# ...          ...           ...           ...      ...       ...      ...
# 204248    204249  4.709300e+11  4.709300e+11       47        93     5201
# 204249    204250  4.709300e+11  4.709300e+11       47        93     5809
# 204250    204251  4.709300e+11  4.709300e+11       47        93     3400
# 204251    204252  4.709300e+11  4.709300e+11       47        93     1400
# 204252    204253  4.715700e+11  4.715700e+11       47       157    21746
#
#         BLKGRPCE    CSA                              CSA_Name     CBSA  ...  \
# ...

# %%
tn_walk['CSA_Name'].value_counts()
# Out:
# CSA_Name
# Nashville-Davidson--Murfreesboro, TN     1080
# Memphis-Forrest City, TN-MS-AR            696
# Knoxville-Morristown-Sevierville, TN      667
# Chattanooga-Cleveland-Dalton, TN-GA       394
# Johnson City-Kingsport-Bristol, TN-VA     277
# Jackson-Brownsville, TN                   146
# Martin-Union City, TN                      53
# Name: count, dtype: int64

# %%
resources_df = pd.read_csv('../data/resource_mapping_by_county.csv')

# %%
resources_df
# Out:
#                                                     Year Agency_ID  \
# 0                                                   2015       DCS
# 1                                                   2015       DCS
# 2                                                   2015       DCS
# 3                                                   2015       DCS
# 4                                                   2015       DCS
# ...                                                  ...       ...
# 29363                                               2022       DOE
# 29364                                               2022       DOE
# 29365                                               2022       DOE
# 29366                                               2022       DOE
# 29367  Note:  '*'  means either data are not reported...       NaN
#
#                              Agency_Name                  Program_Name  \
# 0      Department of Children's Services  Custody & Truancy Prevention
# ...

# %%
resources_df.rename(columns = {'Expenditure': 'amount'})
# Out:
#                                                     Year Agency_ID  \
# 0                                                   2015       DCS
# 1                                                   2015       DCS
# 2                                                   2015       DCS
# 3                                                   2015       DCS
# 4                                                   2015       DCS
# ...                                                  ...       ...
# 29363                                               2022       DOE
# 29364                                               2022       DOE
# 29365                                               2022       DOE
# 29366                                               2022       DOE
# 29367  Note:  '*'  means either data are not reported...       NaN
#
#                              Agency_Name                  Program_Name  \
# 0      Department of Children's Services  Custody & Truancy Prevention
# ...
